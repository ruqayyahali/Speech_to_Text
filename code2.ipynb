# %%
# !pip install ibm_watson

# %%
from ibm_watson import SpeechToTextVl
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-0e32b4712484> in <module>
# ----> 1 from ibm_watson import SpeechToTextVl
#       2 from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
#
# ImportError: cannot import name 'SpeechToTextVl'

# %%
apikey = '5xMlya_mxk3a-U1d-0ALtOGpYvUQ1djSzdI6oBF6sq1X'
url = 'https://api.au-syd.speech-to-text.watson.cloud.ibm.com/instances/7b7fefb6-410f-4587-974c-b07ce0022327'

# %%
authenticator = IAMAuthenticator(apikey)
stt = SpeechToTexttV1(authenticator=authenticator)
stt.set_service-url(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-daf031d4dd69> in <module>
# ----> 1 authenticator = IAMAuthenticator(apikey)
#       2 stt = SpeechToTexttV1(authenticator=authenticator)
#       3 stt.set_service-url(url)
#
# NameError: name 'IAMAuthenticator' is not defined

# %%
with open ('voic.ogg','rb') as f:
    res = stt.recognize(audio=f, content_type='audio/ogg', model='en-US_NarrowbandModel', continuous=True).get_result()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-fe99702bb78b> in <module>
# ----> 1 with open ('voic.ogg','rb') as f:
#       2     res = stt.recognize(audio=f, content_type='audio/ogg', model='en-US_NarrowbandModel', continuous=True).get_result()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'voic.ogg'

# %%
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c08785e04264> in <module>
# ----> 1 res
#
# NameError: name 'res' is not defined

# %%
text = res['result'][0]['alternatives'][0]['transcript']
text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-3e65fe907d4b> in <module>
# ----> 1 text = res['result'][0]['alternatives'][0]['transcript']
#       2 text
#
# NameError: name 'res' is not defined

# %%
confidence = res['result'][0]['alternatives'][0]['confidence']
confidence
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-480d9f62f172> in <module>
# ----> 1 confidence = res['result'][0]['alternatives'][0]['confidence']
#       2 confidence
#
# NameError: name 'res' is not defined

# %%
with open ('text.text', 'w') as out:
    out.writalines(text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-8e2203a57d85> in <module>
#       1 with open ('text.text', 'w') as out:
# ----> 2     out.writalines(text)
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'writalines'
